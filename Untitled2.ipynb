# %%
code = """
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# 🎯 Set Title
st.title("🚀 Petroleum & Gas Production Prediction Dashboard")

# 📂 Load Data
df_petroleum = pd.read_csv("clean_petroleumflowdata.csv")
df_gas = pd.read_csv("clean_gasProduction.csv")

# 📊 Sidebar for Selection
st.sidebar.header("🔍 Select Visualization")
option = st.sidebar.radio("Choose Dataset:", ["Petroleum Data", "Gas Production"])

# 📌 Show Dataset
if option == "Petroleum Data":
    st.subheader("📜 Petroleum Dataset Preview")
    st.write(df_petroleum.head())

    # 🛢️ Line Chart for Petroleum Flow
    st.subheader("📈 Petroleum Flow Over Time")
    fig, ax = plt.subplots()
    ax.plot(df_petroleum["Date"], df_petroleum["Total flow"], marker="o", linestyle="-", color="blue")
    ax.set_xlabel("Date")
    ax.set_ylabel("Total Flow")
    ax.set_title("Petroleum Flow Over Time")
    plt.xticks(rotation=45)
    st.pyplot(fig)

elif option == "Gas Production":
    st.subheader("📜 Gas Production Dataset Preview")
    st.write(df_gas.head())

    # 🔥 Line Chart for Gas Production
    st.subheader("📈 Gas Production Over Time")
    fig, ax = plt.subplots()
    ax.plot(df_gas["Time"], df_gas["Production"], marker="s", linestyle="-", color="green")
    ax.set_xlabel("Time")
    ax.set_ylabel("Production")
    ax.set_title("Gas Production Over Time")
    plt.xticks(rotation=45)
    st.pyplot(fig)

# 🎯 Footer
st.markdown("### ✅ Developed by Saloni Sharma 🚀")
"""

# ✅ Write to a file
with open("app.py", "w") as file:
    file.write(code)

print("✅ app.py file created successfully!")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[1], line 52
#      50 # ✅ Write to a file
#      51 with open("app.py", "w") as file:
# ---> 52     file.write(code)
#      54 print("✅ app.py file created successfully!")
#
# File C:\ProgramData\anaconda3\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f3af' in position 84: character maps to <undefined>

# %%
code = """
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# Set Title
st.title("Petroleum & Gas Production Prediction Dashboard")

# Load Data
df_petroleum = pd.read_csv("clean_petroleumflowdata.csv")
df_gas = pd.read_csv("clean_gasProduction.csv")

# Sidebar for Selection
st.sidebar.header("Select Visualization")
option = st.sidebar.radio("Choose Dataset:", ["Petroleum Data", "Gas Production"])

# Show Dataset
if option == "Petroleum Data":
    st.subheader("Petroleum Dataset Preview")
    st.write(df_petroleum.head())

    # Line Chart for Petroleum Flow
    st.subheader("Petroleum Flow Over Time")
    fig, ax = plt.subplots()
    ax.plot(df_petroleum["Date"], df_petroleum["Total flow"], marker="o", linestyle="-", color="blue")
    ax.set_xlabel("Date")
    ax.set_ylabel("Total Flow")
    ax.set_title("Petroleum Flow Over Time")
    plt.xticks(rotation=45)
    st.pyplot(fig)

elif option == "Gas Production":
    st.subheader("Gas Production Dataset Preview")
    st.write(df_gas.head())

    # Line Chart for Gas Production
    st.subheader("Gas Production Over Time")
    fig, ax = plt.subplots()
    ax.plot(df_gas["Time"], df_gas["Production"], marker="s", linestyle="-", color="green")
    ax.set_xlabel("Time")
    ax.set_ylabel("Production")
    ax.set_title("Gas Production Over Time")
    plt.xticks(rotation=45)
    st.pyplot(fig)

# Footer
st.markdown("### Developed by Saloni Sharma")
"""

# ✅ Write to a file with UTF-8 encoding
with open("app.py", "w", encoding="utf-8") as file:
    file.write(code)

print("✅ app.py file created successfully!")
# Out:
# ✅ app.py file created successfully!

# %%
pip install --upgrade streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.8 MB 6.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.8 MB 5.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.8 MB 4.5 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.8 MB 4.4 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.8 MB 4.3 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.8 MB 4.2 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.8 MB 4.1 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.8 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.8 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 4.1 MB/s eta 0:00:01
# ...
